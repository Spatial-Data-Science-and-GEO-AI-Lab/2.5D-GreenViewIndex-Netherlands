# %%
# data preprocessing
import rasterio
from rasterio.mask import mask
from shapely.geometry import Polygon
from rasterio.plot import show
import matplotlib.pyplot as plt
from rasterio.enums import Resampling
import numpy as np

#viewshed
from uuid import uuid1
from os import makedirs
from affine import Affine
from os.path import exists
from math import exp, hypot
# from time import perf_counter
from rasterio import open as rio_open
from rasterio.transform import rowcol, xy
from skimage.draw import line, disk, circle_perimeter
from numpy import zeros, unique, multiply, array, column_stack
from tqdm import tqdm

# %%
# check the metadata, coordinate system and elavation on files
with rasterio.open('data/DSM_merged.tif') as src:
    print("DSM CRS:", src.crs)
    print("Resolution: {}".format(resolution))
    
    
with rasterio.open('data/DTM.tif') as src:
    print("DTM CRS:", src.crs)
    resolution = src.res # resolution
    print("Resolution: {}".format(resolution))
    
with rasterio.open('data/20200629_gm_Bomenkaart_v2_resampled.tif') as src:
    print("Greeness CRS:", src.crs)
    resolution = src.res # resolution
    print("Resolution: {}".format(resolution))
# Out:
# DSM CRS: LOCAL_CS["Amersfoort / RD New",UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Resolution: (5.0, 5.0)
# DTM CRS: LOCAL_CS["Amersfoort / RD New",UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Resolution: (5.0, 5.0)
# Greeness CRS: LOCAL_CS["Amersfoort / RD New",UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Resolution: (5.0, 5.0)

# %%
import osmnx as ox
import geopandas as gpd

# region specificaiton
region = "Netherlands"
G = ox.graph_from_place(region, network_type="all") # get all networks for the given region
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G) # convert the graph to a GeoDataFrame

# reproject to the matching projection with dtm and dsm
gdf_nodes = gdf_nodes.to_crs('EPSG:28992')
gdf_edges = gdf_edges.to_crs('EPSG:28992')

# %%
import osmnx as ox

# Bounding box coordinates of the Netherlands
netherlands_bbox = (3.3599, 50.7504, 7.2274, 53.6414)

# Download the street network for the Netherlands
G = ox.graph_from_bbox(netherlands_bbox[1], netherlands_bbox[3], netherlands_bbox[0], netherlands_bbox[2], network_type='all')

# %%
import osmnx as ox
import geopandas as gpd
import time

# region specification
region = "Netherlands"

# start the timer
start_time = time.time()

# get all networks for the given region
G = ox.graph_from_place(region, network_type="all")

# convert the graph to a GeoDataFrame
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)

# reproject to the matching projection with dtm and dsm
gdf_nodes = gdf_nodes.to_crs('EPSG:28992')
gdf_edges = gdf_edges.to_crs('EPSG:28992')

# end the timer
end_time = time.time()

# calculate the execution time
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

# List of cities
cities = ["Amsterdam, Netherlands", "Rotterdam, Netherlands", "Utrecht, Netherlands", "The Hague, Netherlands"]

# Initialize empty lists to store the results
all_gdf_nodes = []
all_gdf_edges = []

# Iterate over cities with progress tracking
total_cities = len(cities)
for i, city in enumerate(cities):
    G = ox.graph_from_place(city, network_type="all")
    gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)

    # Reproject to the matching projection with dtm and dsm
    gdf_nodes = gdf_nodes.to_crs('EPSG:28992')
    gdf_edges = gdf_edges.to_crs('EPSG:28992')
    
    # Append the results to the respective lists
    all_gdf_nodes.append(gdf_nodes)
    all_gdf_edges.append(gdf_edges)
    
    # Print progress
    progress = f"{i+1}/{total_cities}"
    print(f"Processing city {city} ({progress})")

# Merge all the GeoDataFrames into a single GeoDataFrame
merged_gdf_nodes = gpd.GeoDataFrame(pd.concat(all_gdf_nodes, ignore_index=True))
merged_gdf_edges = gpd.GeoDataFrame(pd.concat(all_gdf_edges, ignore_index=True))

# %%
# Save the merged edges as a GeoPackage file

edges_geometry = merged_gdf_edges[["geometry"]]

# Save the edges' geometry as a GeoPackage file
edges_output_file = 'merged_edges.gpkg'
edges_geometry.to_file(edges_output_file, driver='GPKG')

# %%
merged_gdf_edges
# Out:
#                                 osmid  oneway  \
# 0                             4745774   False
# 1       [38297120, 7372610, 38297119]   False
# 2                             7372614    True
# 3                            37481780   False
# 4                            37481780   False
# ...                               ...     ...
# 420134                     1174006904   False
# 420135                     1174006904   False
# 420136                      144189802    True
# 420137                     1174006903   False
# 420138                      144189802    True
#
#                                               name       highway width  \
# 0                                        Raamsteeg      cycleway  1.80
# 1       [Joes Kloppenburgbrug, Oude Spiegelstraat]  unclassified   NaN
# 2                                           Singel   residential   NaN
# 3                         Wilhelmina Blombergplein    pedestrian   NaN
# ...

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 5), dpi=100)

# visualise the sampled DSM file
dsm = rasterio.open("data/DSM_merged.tif", driver="GTiff")
show(dsm, title='Digital Surface Model', cmap='gist_ncar', ax=ax[0])
dsm.close()

# visualise the sampled DTM file
dtm = rasterio.open("data/DTM.tif", driver="GTiff")
show(dtm, title='Digital Terrain Model', cmap='gist_ncar', ax=ax[1])
dtm.close()

# %% [markdown]
# # Download DSM/DTM files from AHN3

# %%
import requests
import os

with open('Data/AHN3/tiles_list_dtm.txt', 'r') as file:
    tile_urls = file.read().splitlines()

# Specify the output directory
output_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3/tiles_dtm'

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Track the progress of downloaded tiles
total_tiles = len(tile_urls)
downloaded_tiles = 0

# Download the tiles and save them to the output directory
for url in tile_urls:
    file_name = url.split('/')[-1]
    output_path = os.path.join(output_directory, file_name)
    response = requests.get(url)
    with open(output_path, 'wb') as f:
        f.write(response.content)
    print("Downloaded", file_name)
    print("Saved to", os.path.abspath(output_path))

    # Update the progress
    downloaded_tiles += 1
    print("Progress: {}/{}".format(downloaded_tiles, total_tiles))

print("Download complete!")
# Out:
# Downloaded M_02EZ1.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_02EZ1.ZIP
# Progress: 1/1371
# Downloaded M_02EZ2.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_02EZ2.ZIP
# Progress: 2/1371
# Downloaded M_02FZ1.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_02FZ1.ZIP
# Progress: 3/1371
# Downloaded M_02FZ2.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_02FZ2.ZIP
# Progress: 4/1371
# Downloaded M_01GN1.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_01GN1.ZIP
# Progress: 5/1371
# Downloaded M_03DZ1.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_03DZ1.ZIP
# Progress: 6/1371
# Downloaded M_01GN2.ZIP
# Saved to C:\Users\Ondrej\2.5D-GreenViewIndex-Netherlands\Data\AHN3\tiles_dtm\M_01GN2.ZIP
# Progress: 7/1371
# Downloaded M_01HN1.ZIP
# ...

# %%
import zipfile
import os

working_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3/tiles'
output_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3'

os.makedirs(output_directory, exist_ok=True)  # Create the output directory if it doesn't exist

extracted_directory = os.path.join(output_directory, 'extracted')
os.makedirs(extracted_directory, exist_ok=True)  # Create the 'extracted' directory

for file in os.listdir(working_directory):
    if zipfile.is_zipfile(file):
        with zipfile.ZipFile(file) as item:
            item.extractall(extracted_directory)
            print("Extracted files from:", file)

print("Files extracted and saved to:", extracted_directory)
# Out:
# Files extracted and saved to: C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3\extracted

# %%
import os
import rasterio
from rasterio.merge import merge

extracted_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3/extracted'
output_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3'
output_file = os.path.join(output_directory, 'merged.tif')

os.makedirs(output_directory, exist_ok=True) 

tif_files = []
for root, dirs, files in os.walk(extracted_directory):
    tif_files += [os.path.join(root, file) for file in files if file.endswith('.TIF')]

arr, out_trans = merge(tif_files)
arr
# Out:
# KeyboardInterrupt
#
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "C:\Users\Ondrej\miniconda3\lib\logging\__init__.py", line 1506, in log
#     if not isinstance(level, int):
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
import os
import rasterio
from rasterio.merge import merge
from tqdm import tqdm

extracted_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3/extracted'
output_directory = 'C:/Users/Ondrej/2.5D-GreenViewIndex-Netherlands/Data/AHN3'
output_file = os.path.join(output_directory, 'merged.tif')

os.makedirs(output_directory, exist_ok=True) 

tif_files = []
for root, dirs, files in os.walk(extracted_directory):
    tif_files += [os.path.join(root, file) for file in files if file.endswith('.TIF')]

# Get the total number of TIFF files
total_files = len(tif_files)
print(total_files)

# Merge the TIFF files
merged_arr, out_trans = merge(tif_files)

# Create the output file
with rasterio.open(tif_files[0]) as src:
    meta = src.meta

meta.update({"driver": "GTiff",
             "height": merged_arr.shape[1],
             "width": merged_arr.shape[2],
             "transform": out_trans})

# Save the merged TIFF file
with rasterio.open(output_file, "w", **meta) as dst:
    dst.write(merged_arr)
# Out:
# 1371
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 21
#      18 print(total_files)
#      20 # Merge the TIFF files
# ---> 21 merged_arr, out_trans = merge(tif_files)
#      23 # Create the output file
#      24 with rasterio.open(tif_files[0]) as src:
#
# File ~\miniconda3\lib\site-packages\rasterio\merge.py:293, in merge(datasets, bounds, res, nodata, dtype, precision, indexes, output_count, resampling, method, target_aligned_pixels, dst_path, dst_kwds)
#     290     out_profile["nodata"] = nodata
#     292 # create destination array
# --> 293 dest = np.zeros((output_count, output_height, output_width), dtype=dt)
#     295 if nodata is not None:
#     296     nodataval = nodata
#
# MemoryError: Unable to allocate 12.6 GiB for an array with shape (1, 62500, 54000) and data type float32
